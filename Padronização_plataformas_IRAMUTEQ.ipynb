# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoszigethy/introducao-a-data-science/blob/master/Padroniza%C3%A7%C3%A3o_plataformas_IRAMUTEQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Abre o arquivo de texto contendo todos os resumos das teses e dissertações
input = open('/content/drive/MyDrive/Plataformas_Preliminar/Padronização/v4/resumos_original_rev(filtrado)_final.txt', "rt")

# cria um arquivo de sáida que vai conter as modificações
output = open("plataformas_replaced_v1.txt", "wt")

# %%
# Cria uma estrutura de repetição onde todos os caracteres se tornam minúsculas e se procede a substituição de palavras e símbolos

for line in input:
  output.write(line.lower()
          .replace("organização para a cooperação e desenvolvimento econômico (ocde)","organização_para_a_cooperação_e_desenvolvimento_econômico")
          .replace("sistema nacional de informações e indicadores cultural (sniic)","sistema_nacional_de_informações_e_indicadores_cultural")
          .replace("constituição_da_república federativa do brasil de 1988","constituição_da_república_federativa_do_brasil_de_1988")
          .replace("lei geral_de_proteção_de_dados lei_13.709/2018 (lgpd)","lei_de_proteção_de_dados_pessoais")
          .replace("federação da agricultura do estado do paraná (faep)","federação_da_agricultura_do_estado_do_paraná")
          .replace("conselho administrativo de defesa econômica (cade)","conselho_administrativo_de_defesa_econômica_(cade)")
          .replace("universidade federal do rio_grande do norte_ ufrn","universidade_federal_do_rio_grande_do_norte")
          .replace("tecnologia da informação e das telecomunicações","tecnologias_da_informação_e_comunicação")
          .replace("tecnologias da informação_e_comunicação (tics)","tecnologias_da_informação_e_comunicação")
          .replace("tecnologias de informação_e_comunicação (tics)","tecnologias_da_informação_e_comunicação")
          .replace("gestão estratégica de recursos humanos (gerh)","gestão_estratégica_de_recursos_humanos")
          .replace("universidade federal do rio_de_janeiro (ufrj)","universidade_federal_do_rio_de_janeiro")
          .replace("superintendência de seguros privados (susep)","superintendência_de_seguros_privados")
          .replace("tecnologia da informação e comunicação (tic)","tecnologias_da_informação_e_comunicação")
          .replace("tecnologias da informação e da comunicação","tecnologias_da_informação_e_comunicação")
          .replace("catálogo de teses e dissertações da capes","catálogo_de_teses_e_dissertações_da_capes")
          .replace("classificação brasileira de ocupações cbo","classificação_brasileira_de_ocupações")
          .replace("parâmetros curriculares nacionais (pcns)","parâmetros_curriculares_nacionais_(pcns)")
          .replace("economia sob_demanda (on_demandeconomy)","economia_sob_demanda")
          .replace("mercado de carbono florestal brasileiro","mercado_de_carbono_florestal_brasileiro")
          .replace("motoristas de aplicativos de transporte","motorista_de_aplicativo")
          .replace("tecnologias da comunicação e informação","tecnologias_da_informação_e_comunicação")
          .replace("tecnologias da informação e comunicação","tecnologias_da_informação_e_comunicação")
          .replace("tecnologias da informação_e_comunicação","tecnologias_da_informação_e_comunicação")
          .replace("tecnologias de informação e comunicação","tecnologias_da_informação_e_comunicação")
          .replace("tecnologias de informação_e_comunicação","tecnologias_da_informação_e_comunicação")
          .replace("constituição_federal de 1988 (cf/1988)","constituição_da_república_federativa_do_brasil_de_1988")
          .replace("lei de proteção de dados_pessoais lgpd","lei_de_proteção_de_dados_pessoais")
          .replace("plataformas digitais de mídias sociais","redes_sociais")
          .replace("sistema de pagamentos brasileiro (spb)","sistema_de_pagamentos_brasileiro")
          .replace("tecnologia da informação_e_comunicação","tecnologias_da_informação_e_comunicação")
          .replace("universidade federal do rio de janeiro","universidade_federal_do_rio_de_janeiro")
          .replace("universidade federal do rio_de_janeiro","universidade_federal_do_rio_de_janeiro")
          .replace("base nacional comum curricular (bncc)","base_nacional_comum_curricular")
          .replace("comissão de valores mobiliários (cvm)","comissão_de_valores_mobiliários")
          .replace("plataformas de economia compartilhada","plataformas_de_economia_compartilhada")
          .replace("plataformas digitais de intermediação","plataformas_digitais_de_intermediação")
          .replace("plataformas digitais de redes sociais","redes_sociais")
          .replace("atividades de economia compartilhada","atividades_de_economia_compartilhada")
          .replace("código de defesa do consumidor (cdc)","código_de_defesa_do_consumidor")
          .replace("transporte individual de passageiros","transporte_individual_de_passageiros")
          .replace("sistemas tutores inteligentes (sti)","sistemas_tutores_inteligentes")
          .replace("ambientes virtuais de aprendizagem","ambientes_virtuais_de_aprendizagem")
          .replace("universidade federal de uberlândia","universidade_federal_de_uberlândia")
          .replace("constituição_da_república de 1988","constituição_da_república_federativa_do_brasil_de_1988")
          .replace("processo de ensino e aprendizagem","processo_de_ensino_e_aprendizagem")
          .replace("revisão sistemática da literatura","revisão_sistemática_da_literatura")
          .replace("empresariamento da informalidade","empresariamento_da_informalidade")
          .replace("plataformas locais de mobilidade","plataformas_locais_de_mobilidade")
          .replace("sistema de informação geográfica","sistema_de_informação_geográfica")
          .replace("universidade de marília (unimar)","universidade_de_marília")
          .replace("cadeias globais de valor (cgvs)","cadeias_globais_de_valor")
          .replace("global catastrophic risks (gcr)","global_catastrophic_risks")
          .replace("microempreendedores individuais","microempreendedores_individuais")
          .replace("ordenamento jurídico brasileiro","ordenamento_jurídico_brasileiro")
          .replace("plataformas de compartilhamento","sharing_economy")
          .replace("universidade de mogi das cruzes","universidade_de_mogi_das_cruzes")
          .replace("base nacional comum curricular","base_nacional_comum_curricular")
          .replace("federal trade commission (ftc)","federal_trade_commission")
          .replace("quarta_revolução_industrial.0.","quarta_revolução_industrial ")
          .replace("plataformas digitais de mídias","redes_sociais")
          .replace("plataformas digitais de redes","plataformas_digitais_de_redes")
          .replace("economias de compartilhamento","sharing_economy")
          .replace("informação e comunicação tics","tecnologias_da_informação_e_comunicação")
          .replace("constituição_federal de 1988","constituição_da_república_federativa_do_brasil_de_1988")
          .replace("cooperativismo de plataforma","cooperativismo_de_plataforma")
          .replace("gases de efeito estufa (GEE)","gases de efeito estufa (GEE)")
          .replace("rede mundial de computadores","internet")
          .replace("plataformas de redes sociais","redes_sociais")
          .replace("economia de compartilhamento","sharing_economy")
          .replace("economia do compartilhamento","sharing_economy")
          .replace("superior tribunal de justiça","superior_tribunal_de_justiça")
          .replace("desenvolvimento sustentável","desenvolvimento_sustentável")
          .replace("desenvolvimento tecnológico","desenvolvimento_tecnológico")
          .replace("ecossistema das plataformas","ecossistema_de_plataformas")
          .replace("gestão do conhecimento (gc)","gestão_do_conhecimento")
          .replace("open strategic design (osd)","open_strategic_design")
          .replace("política externa brasileira","política_externa_brasileira")
          .replace("procedimentos metodológicos","procedimentos_metodológicos")
          .replace("projeto de multiletramentos","projeto_de_multiletramentos")
          .replace("proteção dos dados pessoais","proteção_de_dados_pessoais")
          .replace("quarta revolução industrial","quarta_revolução_industrial")
          .replace("informação e da comunicação","tecnologias_da_informação_e_comunicação")
          .replace("análise de conteúdo bardin","análise_de_conteúdo_bardin")
          .replace("business intelligence (bi)","business_intelligence")
          .replace("ciência da informação (ci)","ciência_da_informação")
          .replace("ciências sociais aplicadas","ciências_sociais_aplicadas")
          .replace("cooperativas de plataforma","cooperativismo_de_plataforma")
          .replace("geral de proteção de dados","geral_de_proteção_de_dados")
          .replace("levantamento bibliográfico","levantamento_bibliográfico")
          .replace("pesquisa & desenvolvimento","pesquisa_e_desenvolvimento")
          .replace("pesquisa e desenvolvimento","pesquisa_e_desenvolvimento")
          .replace("pessoas em situação de rua","pessoas_em_situação_de_rua")
          .replace("proteção de dados pessoais","proteção_de_dados_pessoais")
          .replace("tecnologias de comunicação","tecnologias_da_informação_e_comunicação")
          .replace("world economic forum (wef)","world_economic_forum")
          .replace("aplicativos de transporte","aplicativos_de_transporte")
          .replace("capitalismo de plataforma","capitalismo_de_plataforma")
          .replace("capitalismo da vigilância","capitalismo_de_vigilância")
          .replace("capitalismo de vigilância","capitalismo_de_vigilância")
          .replace("constituição da república","constituição_da_república_federativa_do_brasil_de_1988")
          .replace("plataformas colaborativas","cooperativismo_de_plataforma")
          .replace("desenvolvimento econômico","desenvolvimento_econômico")
          .replace("digitalização da economia","digitalização_da_economia")
          .replace("instituições democráticas","instituições_democráticas")
          .replace("internet_das_coisas (iot)","internet_das_coisas")
          .replace("meio ambiente do trabalho","meio_ambiente_do_trabalho")
          .replace("micro e pequenas empresas","micro_e_pequenas_empresas")
          .replace("modelo de inovação aberta","modelo_de_inovação_aberta")
          .replace("motoristas de aplicativos","motorista_de_aplicativo")
          .replace("plataformas de tecnologia","plataformas_de_tecnologia")
          .replace("popularização da internet","popularização_da_internet")
          .replace("procedimento metodológico","procedimentos_metodológicos")
          .replace("redes de compartilhamento","redes_de_compartilhamento")
          .replace("sistemática da literatura","sistemática_da_literatura")
          .replace("technology readness index","technology_readness_index")
          .replace("tecnologias da informação","tecnologias_da_informação_e_comunicação")
          .replace("universidade de são paulo","universidade_de_são_paulo")
          .replace("internet of things (iot)","internet_das_coisas")
          .replace("motoristas de aplicativo","motorista_de_aplicativo")
          .replace("pesquisas bibliográficas","pesquisas_bibliográficas")
          .replace("planejamento estratégico","planejamento_estratégico")
          .replace("plataformas de streaming","plataformas_de_streaming")
          .replace("precarização do trabalho","precarização_do_trabalho")
          .replace("processo de precarização","processo_de_precarização")
          .replace("sistema de gerenciamento","sistema_de_gerenciamento")
          .replace("sistemas de recomendação","sistemas_de_recomendação")
          .replace("subordinação algorítmica","subordinação_algorítmica")
          .replace("informação e comunicação","tecnologias_da_informação_e_comunicação")
          .replace("tecnologia da informação","tecnologias_da_informação_e_comunicação")
          .replace("tributário internacional","tributário_internacional")
          .replace("conhecimento científico","conhecimento_científico")
          .replace("constituição brasileira","constituição_da_república_federativa_do_brasil_de_1988")
          .replace("economia de plataformas","economia_de_plataformas")
          .replace("educação ambiental (ea)","educação_ambiental")
          .replace("histórias em quadrinhos","histórias_em_quadrinhos")
          .replace("inteligência artificial","inteligência_artificial")
          .replace("intenção comportamental","intenção_comportamental")
          .replace("internet das coisas iot","internet_das_coisas")
          .replace("marco civil da internet","marco_civil_da_internet")
          .replace("metodologia de pesquisa","metodologia_de_pesquisa")
          .replace("observação participante","observação_participante")
          .replace("organização do trabalho","organização_do_trabalho")
          .replace("pessoas com deficiência","pessoas_com_deficiência")
          .replace("plataformas de economia","plataformas_de_economia")
          .replace("processo de legitimação","processo_de_legitimação")
          .replace("produção e distribuição","produção_e_distribuição")
          .replace("são gonçalo do amarante","são_gonçalo_do_amarante")
          .replace("serviços compartilhados","serviços_compartilhados")
          .replace("sociedade contemporânea","sociedade_contemporânea")
          .replace("sociedade da informação","sociedade_da_informação")
          .replace("tecnologias disruptivas","tecnologias_disruptivas")
          .replace("trabalho dos motoristas","trabalho_dos_motoristas")
          .replace("vantagens competitivas ","vantagem_competitiva")
          .replace("atividades de economia","atividades_de_economia")
          .replace("comércio internacional","comércio_internacional")
          .replace("defesa da concorrência","defesa_da_concorrência")
          .replace("desemprego tecnológico","desemprego_tecnológico")
          .replace("direito constitucional","direito_constitucional")
          .replace("economia de plataforma","economia_de_plataformas")
          .replace("economia informacional","economia_informacional")
          .replace("empresas de tecnologia","empresas_de_tecnologia")
          .replace("experiência de consumo","experiência_de_consumo")
          .replace("experiência do usuário","experiência_de_uso")
          .replace("gestão do conhecimento","gestão_do_conhecimento")
          .replace("inovações tecnológicas","inovações_tecnológicas")
          .replace("instituição financeira","instituição_financeira")
          .replace("internet of things iot","internet_das_coisas")
          .replace("jair messias bolsonaro","jair_bolsonaro")
          .replace("legislação trabalhista","legislação_trabalhista")
          .replace("liberdade de expressão","liberdade_de_expressão")
          .replace("Ministério da Educação","Ministério_da_Educação")
          .replace("pesquisa bibliográfica","pesquisa_bibliográfica")
          .replace("processamento de dados","processamento_de_dados")
          .replace("processo de construção","processo_de_construção")
          .replace("redes sociais digitais","redes_sociais")
          .replace("resolução de conflitos","resolução_de_conflitos")
          .replace("economia compartilhada","sharing_economy")
          .replace("sites de redes sociais","sites_de_redes_sociais")
          .replace("trabalho institucional","trabalho_institucional")
          .replace("uberização do trabalho","uberização_do_trabalho")
          .replace("universidades públicas","universidades_públicas")
          .replace("vantagens competitivas","vantagem_competitiva")
          .replace("abordagem qualitativa","abordagem_qualitativa")
          .replace("administração pública","administração_pública")
          .replace("anistia internacional","anistia_internacional")
          .replace("atividades econômicas","atividades_econômicas")
          .replace("canais de comunicação","canais_de_comunicação")
          .replace("ciência da computação","ciência_da_computação")
          .replace("ciência da informação","ciência_da_informação")
          .replace("condições de trabalho","condições_de_trabalho")
          .replace("criadores de conteúdo","criadores_de_conteúdo")
          .replace("direitos fundamentais","direito_fundamental")
          .replace("direitos trabalhistas","direitos_trabalhistas")
          .replace("dispositivos digitais","dispositivos_digitais")
          .replace("divulgação científica","divulgação_científica")
          .replace("divulgação da ciência","divulgação_científica")
          .replace("economia digitalizada","economia_digital")
          .replace("ecossistemas digitais","ecossistemas_digitais")
          .replace("financiamento público","financiamento_público")
          .replace("grupo dos vinte (g20)","g20")
          .replace("indústria fonográfica","indústria_fonográfica")
          .replace("inteligência de dados","inteligência_de_dados")
          .replace("levantamento de dados","levantamento_de_dados")
          .replace("moedas virtuais (mvs)","moedas_virtuais")
          .replace("natureza exploratória","natureza_exploratória")
          .replace("nível de escolaridade","nível_de_escolaridade")
          .replace("participação política","participação_política")
          .replace("pesquisa experimental","pesquisa_experimental")
          .replace("pesquisa exploratória","pesquisa_exploratória")
          .replace("pesquisa participante","pesquisa_participante")
          .replace("plataformas de ensino","plataformas_de_ensino")
          .replace("portais de periódicos","portais_de_periódicos")
          .replace("prestação de serviços","prestação_de_serviços")
          .replace("relações trabalhistas","relações_trabalhistas")
          .replace("revisão bibliográfica","revisão_bibliográfica")
          .replace("revisão da literatura","revisão_de_literatura")
          .replace("revisão de literatura","revisão_de_literatura")
          .replace("revisão na literatura","revisão_de_literatura")
          .replace("serviços de streaming","serviços_de_streaming")
          .replace("economia colaborativa","sharing_economy")
          .replace("sistemas inteligentes","sistemas_inteligentes")
          .replace("transformação digital","transformação_digital")
          .replace("ambiente do trabalho","ambiente_do_trabalho")
          .replace("analisar os impactos","analisar_os_impactos")
          .replace("aplicativos digitais","aplicativos_digitais")
          .replace("área do conhecimento","área_do_conhecimento")
          .replace("atividade econômica ","atividades_econômicas")
          .replace("audiovisual infantil","audiovisual_infantil")
          .replace("câmara dos deputados","câmara_dos_deputados")
          .replace("capacidades digitais","capacidades_digitais")
          .replace("capacidades estatais","capacidades_estatais")
          .replace("cidades inteligentes","cidades_inteligentes")
          .replace("comunidades virtuais","comunidades_virtuais")
          .replace("constituição de 1988","constituição_da_república_federativa_do_brasil_de_1988")
          .replace("constituição federal","constituição_da_república_federativa_do_brasil_de_1988")
          .replace("consumo colaborativo","consumo_colaborativo")
          .replace("economia sob_demanda","economia_sob_demanda")
          .replace("educação a distância","educação_a_distância")
          .replace("engajamento político","engajamento_político")
          .replace("estudantes do ensino","estudantes_do_ensino")
          .replace("evolução tecnológica","evolução_tecnológica")
          .replace("inovação tecnológica","inovações_tecnológicas")
          .replace("jornalismo literário","jornalismo_literário")
          .replace("letramentos digitais","letramentos_digitais")
          .replace("línguas estrangeiras","línguas_estrangeiras")
          .replace("linguística aplicada","linguística_aplicada")
          .replace("marketing científico","marketing_científico")
          .replace("natureza qualitativa","natureza_qualitativa")
          .replace("objetos educacionais","objetos_educacionais")
          .replace("ordenamento jurídico","ordenamento_jurídico")
          .replace("participação on_line","participação_online")
          .replace("pesquisa qualitativa","pesquisa_qualitativa")
          .replace("plataformas digitais","plataformas_digitais")
          .replace("plataformas de redes","plataformas_digitais_de_redes")
          .replace("prestador de serviço","prestador_de_serviço")
          .replace("problema de pesquisa","problema_de_pesquisa")
          .replace("processo legislativo","processo_legislativo")
          .replace("processos de negócio","processos_de_negócio")
          .replace("produção de conteúdo","produção_de_conteúdo")
          .replace("redes sociais móveis","redes_sociais")
          .replace("redes sociais online","redes_sociais")
          .replace("região metropolitana","região_metropolitana")
          .replace("relações de trabalho","relações_trabalhistas")
          .replace("revolução industrial","revolução_industrial")
          .replace("sociedade industrial","sociedade_industrial")
          .replace("tecnologias digitais","tecnologias_digitais")
          .replace("plataforma ted talks","ted_talks")
          .replace("teoria institucional","teoria_institucional")
          .replace("texto constitucional","texto_constitucional")
          .replace("trabalho sob demanda","trabalho_sob_demanda")
          .replace("tratamento dos dados","tratamento_dos_dados")
          .replace("universidade pública","universidades_públicas")
          .replace("usuários da internet","usuários_da_internet")
          .replace("vantagem competitiva","vantagem_competitiva")
          .replace("vínculo empregatício","vínculo_empregatício")
          .replace("acesso à informação","acesso_à_informação")
          .replace("análise de conteúdo","análise_de_conteúdo")
          .replace("análise de discurso","análise_de_discurso")
          .replace("análise do discurso","análise_de_discurso")
          .replace("análise do conteúdo","análise_do_conteúdo")
          .replace("análise qualitativa","análise_qualitativa")
          .replace("cidade de são paulo","cidade_de_são_paulo")
          .replace("classe trabalhadora","classe_trabalhadora")
          .replace("comércio eletrônico","comércio_eletrônico")
          .replace("computação em nuvem","computação_em_nuvem")
          .replace("comunicação digital","comunicação_digital")
          .replace("créditos de carbono","créditos_de_carbono")
          .replace("custos de transação","custos_de_transação")
          .replace("direito fundamental","direito_fundamental")
          .replace("direito do trabalho","direitos_trabalhistas")
          .replace("dispositivos móveis","dispositivos_móveis")
          .replace("ecossistema digital","ecossistemas_digitais")
          .replace("educação continuada","educação_continuada")
          .replace("estudo experimental","estudo_experimental")
          .replace("estudo exploratório","estudo_exploratório")
          .replace("expresso es faciais","expressões_faciais")
          .replace("formação de opinião","formação_de_opinião")
          .replace("google sala de aula","google_sala_de_aula")
          .replace("grandes corporações","grandes_empresas")
          .replace("impactos econômicos","impactos_econômicos")
          .replace("indústria da música","indústria_fonográfica")
          .replace("internet das coisas","internet_das_coisas")
          .replace("jornada de trabalho","jornada_de_trabalho")
          .replace("jurídico brasileiro","jurídico_brasileiro")
          .replace("mercado de trabalho","mercado_de_trabalho")
          .replace("método de abordagem","método_de_abordagem")
          .replace("metodologias ativas","metodologias_ativas")
          .replace("modelos de negócios","modelo_de_negócios")
          .replace("mudanças climáticas","mudanças_climáticas")
          .replace("narrativas digitais","narrativas_digitais")
          .replace("parques científicos","parques_científicos")
          .replace("participação social","participação_social")
          .replace("pesquisa documental","pesquisa_documental")
          .replace("prática da partilha","prática_da_partilha")
          .replace("práticas de leitura","práticas_de_leitura")
          .replace("realidade aumentada","realidade_aumentada")
          .replace("redes colaborativas","redes_colaborativas")
          .replace("referencial teórico","referencial_teórico")
          .replace("reforma trabalhista","reforma_trabalhista")
          .replace("relações de consumo","relações_de_consumo")
          .replace("relação de trabalho","relações_trabalhistas")
          .replace("rio grande do norte","rio_grande_do_norte")
          .replace("são josé dos campos","são_josé_dos_campos")
          .replace("setores da economia","setores_da_economia")
          .replace("símbolos pictóricos","símbolos_pictóricos")
          .replace("sistema capitalista","sistema_capitalista")
          .replace("técnica de pesquisa","técnica_de_pesquisa")
          .replace("transporte coletivo","transporte_coletivo")
          .replace("ambientes digitais","ambiente_virtual")
          .replace("ambientes virtuais","ambiente_virtual")
          .replace("análise documental","análise_documental")
          .replace("aplicativos móveis","aplicativos_digitais")
          .replace("bases tecnológicas","bases_tecnológicas")
          .replace("cadeia de produção","cadeia_de_produção")
          .replace("campanha eleitoral","campanha_eleitoral")
          .replace("cidade inteligente","cidade_inteligente")
          .replace("crédito de carbono","créditos_de_carbono")
          .replace("decisões judiciais","decisões_judiciais")
          .replace("democracia digital","democracia_digital")
          .replace("design estratégico","design_estratégico")
          .replace("direito antitruste","direito_antitruste")
          .replace("direito tributário","direito_tributário")
          .replace("economias digitais","economia_digital")
          .replace("educação ambiental","educação_ambiental")
          .replace("ensino fundamental","ensino_fundamental")
          .replace("etnografia digital","etnografia_digital")
          .replace("experiência de uso","experiência_de_uso")
          .replace("governo eletrônico","governo_eletrônico")
          .replace("grau de utilização","grau_de_utilização")
          .replace("hábitos de consumo","hábitos_de_consumo")
          .replace("indústria criativa","indústria_criativa")
          .replace("interações sociais","interações_sociais")
          .replace("jogos de linguagem","jogos_de_linguagem")
          .replace("língua estrangeira","línguas_estrangeiras")
          .replace("mato grosso do sul","mato_grosso_do_sul")
          .replace("modelo de inovação","modelo_de_inovação")
          .replace("modelo de negócios","modelo_de_negócios")
          .replace("motoristas de táxi","motoristas_de_táxi")
          .replace("movimentos sociais","movimentos_sociais")
          .replace("música de concerto","música_de_concerto")
          .replace("partidos políticos","partidos_políticos")
          .replace("plataforma digital","plataformas_digitais")
          .replace("plataformas locais","plataformas_locais")
          .replace("políticas públicas","políticas_públicas")
          .replace("postos de trabalho","postos_de_trabalho")
          .replace("processo de ensino","processo_de_ensino")
          .replace("regulação estatais","regulação_estatal")
          .replace("relação de emprego","relação_de_emprego")
          .replace("retórica analítica","retórica_analítica")
          .replace("serviços públicos ","serviços_públicos")
          .replace("sistema tributário","sistema_tributário")
          .replace("tecnologia digital","tecnologia_digital")
          .replace("tecnologias móveis","tecnologias_móveis")
          .replace("transacional moore","transacional_moore")
          .replace("agentes políticos","agentes_políticos")
          .replace("análise dos dados","análise_de_dados")
          .replace("consumo de música","consumo_de_música")
          .replace("cultura de massas","cultura_de_massas")
          .replace("dados secundários","dados_secundários")
          .replace("discurso político","discurso_político")
          .replace("economia política","economia_política")
          .replace("empresas públicas","empresas_públicas")
          .replace("estudo descritivo","estudo_descritivo")
          .replace("estudos culturais","estudos_culturais")
          .replace("checagem de fatos","fact_checking")
          .replace("força de trabalho","força_de_trabalho")
          .replace("gestão de pessoas","gestão_de_pessoas")
          .replace("instagram stories","instagram_stories")
          .replace("jogos eletrônicos","jogos_eletrônicos")
          .replace("língua portuguesa","língua_portuguesa")
          .replace("linha de pesquisa","linha_de_pesquisa")
          .replace("marketing digital","marketing_digital")
          .replace("material didático","material_didático")
          .replace("mercados digitais","mercados_digitais")
          .replace("mobilidade urbana","mobilidade_urbana")
          .replace("modelo de negócio","modelo_de_negócios")
          .replace("mudança climática","mudanças_climáticas")
          .replace("mundo do trabalho","mundo_do_trabalho")
          .replace("natureza jurídica","natureza_jurídica")
          .replace("negócios digitais","negócios_digitais")
          .replace("observação direta","observação_direta")
          .replace("pesquisa de campo","pesquisa_de_campo")
          .replace("pesquisa empírica","pesquisa_empírica")
          .replace("plataforma online","plataforma_digital")
          .replace("proteção de dados","proteção_de_dados")
          .replace("recursos digitais","recursos_digitais")
          .replace("regulação estatal","regulação_estatal")
          .replace("revolução digital","revolução_digital")
          .replace("rio grande do sul","rio_grande_do_sul")
          .replace("rio_grande do sul","rio_grande_do_sul")
          .replace("segurança pública","segurança_pública ")
          .replace("serviços digitais","serviços_digitais")
          .replace("sociedade em rede","sociedade_em_rede")
          .replace("tomada de decisão","tomada_de_decisão")
          .replace("trabalho autônomo","trabalho_autônomo")
          .replace("trabalho de campo","trabalho_de_campo")
          .replace("trabalho informal","trabalho_informal")
          .replace("acesso à justiça","acesso_à_justiça")
          .replace("ambiente escolar","ambiente_escolar")
          .replace("ambiente digital","ambiente_virtual")
          .replace("ambiente virtual","ambiente_virtual")
          .replace("análise de dados","análise_de_dados")
          .replace("aspectos da vida","aspectos_da_vida")
          .replace("base tecnológica","bases_tecnológicas")
          .replace("caracterí sticas","características")
          .replace("cidade do méxico","cidade_do_méxico")
          .replace("ciência política","ciência_política")
          .replace("ciências sociais","ciências_sociais")
          .replace("coleta dos dados","coleta_de_dados")
          .replace("contexto digital","contexto_digital")
          .replace("criação de valor","criação_de_valor")
          .replace("crise financeira","crise_financeira")
          .replace("direitos humanos","direitos_humanos")
          .replace("direitos sociais","direitos_sociais")
          .replace("distrito federal","distrito_federal")
          .replace("economia digital","economia_digital")
          .replace("on_demandeconomy","economia_sob_demanda")
          .replace("estudos de casos","estudo_de_caso")
          .replace("gestão de ideias","gestão_de_ideias")
          .replace("economia do bico","gig_economy")
          .replace("economia_do_bico","gig_economy")
          .replace("grandes empresas","grandes_empresas")
          .replace("imposto de renda","imposto_de_renda")
          .replace("interação social","interações_sociais")
          .replace("paraísos fiscais","paraísos_fiscais")
          .replace("partido político","partidos_políticos")
          .replace("poder judiciário","poder_judiciário")
          .replace("política externa","política_externa")
          .replace("política pública","políticas_públicas")
          .replace("pontos positivos","pontos_positivos")
          .replace("práticas sociais","práticas_sociais")
          .replace("produção textual","produção_textual")
          .replace("recorte temático","recorte_temático")
          .replace("relação jurídica","relação_jurídica")
          .replace("relações sociais","relações_sociais")
          .replace("setor de seguros","setor_de_seguros")
          .replace("classes sociais","classes_sociais")
          .replace("coleta de dados","coleta_de_dados")
          .replace("crise econômica","crise_econômica")
          .replace("cultura digital","cultura_digital")
          .replace("educação básica","educação_básica")
          .replace("educação física","educação_física")
          .replace("efeitos de rede","efeitos_de_rede")
          .replace("ensino superior","ensino_superior")
          .replace("escola estadual","escola_pública")
          .replace("casos de estudo","estudo_de_caso")
          .replace("estudo de casos","estudo_de_caso")
          .replace("estudos de caso","estudo_de_caso")
          .replace("notícias falsas","fake_news")
          .replace("governo digital","governo_digital")
          .replace("inovação aberta","inovação_aberta")
          .replace("livros digitais","livros_digitais")
          .replace("método dedutivo","método_dedutivo")
          .replace("opinião pública","opinião_pública")
          .replace("pessoa jurídica","pessoa_jurídica")
          .replace("mí dias sociais","plataforma_de_mídias_sociais")
          .replace("mídias digitais","plataforma_de_mídias_sociais")
          .replace("poder econômico","poder_econômico")
          .replace("sharing economy","sharing_economy")
          .replace("situação de rua","situação_de_rua")
          .replace("smart contracts","smart_contracts")
          .replace("sociedade civil","sociedade_civil")
          .replace("trabalho humano","trabalho_humano")
          .replace("america latina","america_latina")
          .replace("atores sociais","atores_sociais")
          .replace("banco de dados","base_de_dados")
          .replace("bases de dados","base_de_dados")
          .replace("belo horizonte","belo_horizonte")
          .replace("câncer de mama","câncer_de_mama")
          .replace("capital social","capital_social")
          .replace("ciência aberta","ciência_aberta")
          .replace("dados pessoais","dados_pessoais")
          .replace("década de 1990","década_de_1990")
          .replace("direito humano","direitos_humanos")
          .replace("escola digital","escola_digital")
          .replace("escola pública","escola_pública")
          .replace("esfera pública","esfera_pública")
          .replace("espírito santo","espírito_santo")
          .replace("estado da arte","estado_da_arte")
          .replace("estados unidos","estados_unidos")
          .replace("estudo de caso","estudo_de_caso")
          .replace("gestão pública","gestão_pública")
          .replace("jair bolsonaro","jair_bolsonaro")
          .replace("jogos digitais","jogos_digitais")
          .replace("meios digitais","meio_digital")
          .replace("meios virtuais","meios_virtuais")
          .replace("new york times","new_york_times")
          .replace("mídias sociais","plataforma_de_mídias_sociais")
          .replace("redes digitais","redes_digitais")
          .replace("rio de janeiro","rio_de_janeiro")
          .replace("santa catarina","santa_catarina")
          .replace("plataforma ted","ted_talks")
          .replace("união europeia","união_europeia")
          .replace("web of science","web_of_science")
          .replace("work on demand","work_on_demand")
          .replace("banco central","banco_central")
          .replace("base de dados","base_de_dados")
          .replace("bases de dado","base_de_dados")
          .replace("caxias do sul","caxias_do_sul")
          .replace("coreia do sul","coreia_do_sul")
          .replace("escala global","escala_global")
          .replace("google trends","google_trends")
          .replace("tele trabalho","home_office")
          .replace("marco teórico","marco_teórico")
          .replace("meio ambiente","meio_ambiente")
          .replace("mundo digital","mundo_digital")
          .replace("poder público","poder_público")
          .replace("pós graduação","pós_graduação")
          .replace("redes sociais","redes_sociais")
          .replace("saúde pública","saúde_pública")
          .replace("setor público","setor_público")
          .replace("stricto sensu","stricto_sensu")
          .replace("valor público","valor_público")
          .replace("acesso livre","acesso_livre")
          .replace("base teórica","base_teórica")
          .replace("campo grande","campo_grande")
          .replace("smart cities","cidades_inteligentes")
          .replace("ensino médio","ensino_médio")
          .replace("especí ficos","específicos")
          .replace("fast fashion","fast_fashion")
          .replace("free lancers","free_lancers")
          .replace("economia gig","gig_economy")
          .replace("gig ecnonomy","gig_economy")
          .replace("google mapas","google_maps")
          .replace("meio digital","meio_digital")
          .replace("mídia social","mídias_sociais")
          .replace("minas gerais","minas_gerais")
          .replace("open banking","open_banking")
          .replace("porto alegre","porto_alegre")
          .replace("porto seguro","porto_seguro")
          .replace("indústrias 4","quarta_revolução_industrial")
          .replace("rede mundial","rede_mundial")
          .replace("rede digital","redes_digitais")
          .replace("sala de aula","sala_de_aula")
          .replace("empresa_uber","uber")
          .replace("via internet","via_internet")
          .replace("web scraping","webscrapping")
          .replace("disponí vel","disponível")
          .replace("era digital","era_digital")
          .replace("expresso es","expressões")
          .replace("home office","home_office")
          .replace("indiví duos","indivíduos")
          .replace("joão pessoa","joão_pessoa")
          .replace("mão de obra","mão_de_obra")
          .replace("marco civil","marco_civil_da_internet")
          .replace("mato grosso","mato_grosso")
          .replace("nova iorque","nova_iorque")
          .replace("porto velho","porto_velho")
          .replace("indústria 4","quarta_revolução_industrial")
          .replace("rede social","rede_social")
          .replace("reino unido","reino_unido")
          .replace("sob demanda","sob_demanda")
          .replace("vida social","vida_social")
          .replace("vote na web","vote_na_web")
          .replace(" partidos "," partidos_políticos ")
          .replace("smart city","cidades_inteligentes")
          .replace("currí culo","currículo")
          .replace("polí ticas","políticas")
          .replace("rio branco","rio_branco")
          .replace("rio grande","rio_grande")
          .replace("século xxi","século_xxi")
          .replace("tempo real","tempo_real")
          .replace("zona norte","zona_norte")
          .replace("anos 2000","anos_2000")
          .replace("boa vista","boa_vista")
          .replace("capí tulo","capítulo")
          .replace("emoc o es","emoções")
          .replace("empí rico","empírico")
          .replace("fake news","fake_news")
          .replace("ouro fino","ouro_fino")
          .replace("possi vel","possível")
          .replace("possí vel","possível")
          .replace("são paulo","são_paulo")
          .replace("século xx","século_xx")
          .replace("ted talks","ted_talks")
          .replace("usua rios","usuários")
          .replace("van dijck","van_dijck")
          .replace("big data","big_data")
          .replace("big tech","big_tech")
          .replace("domí nio","domínio")
          .replace("fí sicos","físicos")
          .replace("new york","new_york")
          .replace("off-line","offline")
          .replace("são luís","são_luís")
          .replace("são luiz","são_luiz")
          .replace("usu rios","usuários")
          .replace("whatzapp","whatsapp")
          .replace(" cf/88 "," constituição_da_república_federativa_do_brasil_de_1988 ")
          .replace(" sniic "," sistema_nacional_de_informações_e_indicadores_cultural ")
          .replace(" susep "," superintendência_de_seguros_privados ")
          .replace("an lise","análise")
          .replace("el pais","el_pais")
          .replace("fí sica","física")
          .replace("mí dias","mídias")
          .replace("ní veis","níveis")
          .replace("on-line","online")
          .replace("sem fio","sem_fio")
          .replace("ví deos","vídeo")
          .replace("web 2.0","web_2_0")
          .replace(" bncc "," base_nacional_comum_curricular ")
          .replace(" cade "," cade ")
          .replace(" faep "," federação_da_agricultura_do_estado_do_paraná ")
          .replace(" gerh "," gestão_estratégica_de_recursos_humanos ")
          .replace(" gcrs "," global_catastrophic_risks ")
          .replace(" ocde "," organização_para_a_cooperação_e_desenvolvimento_econômico ")
          .replace(" tics "," tecnologias_da_informação_e_comunicação ")
          .replace(" tics,"," tecnologias_da_informação_e_comunicação,")
          .replace(" tics."," tecnologias_da_informação_e_comunicação.")
          .replace(" cvgs ","cadeias_globais_de_valor")
          .replace(" lgpd,","lei_de_proteção_de_dados_pessoais")
          .replace("mí dia","mídia")
          .replace(" ufrj ","universidade_federal_do_rio_de_janeiro")
          .replace("ví deo","vídeo")
          .replace(" ci, "," ciência_da_informação,")
          .replace(" cvm "," comissão_de_valores_mobiliários ")
          .replace(" eua "," estados_unidos ")
          .replace(" ftc "," federal_trade_commission ")
          .replace(" gcr "," global_catastrophic_risks ")
          .replace(" iot "," internet_das_coisas ")
          .replace(" iot,"," internet_das_coisas,")
          .replace(" iot."," internet_das_coisas.")
          .replace(" mvs "," moedas_virtuais ")
          .replace(" osd "," open_strategic_design ")
          .replace(" ott "," over_the_top ")
          .replace(" ott."," over_the_top.")
          .replace(" p&d "," pesquisa_e_desenvolvimento ")
          .replace(" sti "," sistemas_tutores_inteligentes ")
          .replace(" sti."," sistemas_tutores_inteligentes.")
          .replace(" usp "," universidade_de_são_paulo ")
          .replace(" cvg ","cadeias_globais_de_valor")
          .replace(" cdc ","código_de_defesa_do_consumidor")
          .replace(" ci "," ciência_da_informação ")
          .replace(" ci."," ciência_da_informação.")
          .replace(" ea "," educação_ambiental ")
          .replace(" gc "," gestão_do_conhecimento ")
          .replace(" gc,"," gestão_do_conhecimento,")
          .replace(" gc."," gestão_do_conhecimento.")
          .replace(" ec "," sharing_economy ")
          .replace(" ec,"," sharing_economy,")
          .replace(" ec."," sharing_economy.") 
          .replace("$","")
          .replace("%","")
          .replace("...","")    
          .replace("®","")
          .replace(" - ",", ")
          .replace(" – ",", ")
          .replace("-","_"))

# %%
# Fecham os arquivos
input.close()
output.close()
